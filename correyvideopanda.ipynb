# %%
import pandas as pd

# %%
df = pd.read_csv('pandas/survey_results_public.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9d6b79eede1c> in <module>
# ----> 1 df = pd.read_csv('pandas/survey_results_public.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
df = pd.read_csv('D:/Users/priyavir/Desktop/pandas/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
schema_df=pd.read_csv('D:/Users/priyavir/Desktop/pandas/survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
people = { "first" : ["corey","jane","john"],
           "last"  : ["shafer","doe","doe"],
            "email" : ["corey@email.com","jane@email.com","john@email.com"]
         }

# %%
people ['email']
# Out:
# ['corey@email.com', 'jane@email.com', 'john@email.com']

# %%
import pandas as pd

# %%
df_people= pd.DataFrame (people)

# %%
df_people
# Out:
#    first    last            email
# 0  corey  shafer  corey@email.com
# 1   jane     doe   jane@email.com
# 2   john     doe   john@email.com

# %%
df_people['email']
# Out:
# 0    corey@email.com
# 1     jane@email.com
# 2     john@email.com
# Name: email, dtype: object

# %%
df_people[['last','email']]
# Out:
#      last            email
# 0  shafer  corey@email.com
# 1     doe   jane@email.com
# 2     doe   john@email.com

# %%
df_people.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df_people.iloc[[0,1]]
# Out:
#    first    last            email
# 0  corey  shafer  corey@email.com
# 1   jane     doe   jane@email.com

# %%
df_people.iloc[[0,1],2]
# Out:
# 0    corey@email.com
# 1     jane@email.com
# Name: email, dtype: object

# %%
df_people.loc[[0,1],'email']
# Out:
# 0    corey@email.com
# 1     jane@email.com
# Name: email, dtype: object

# %%
import pandas as pd

# %%
df = pd.read_csv('D:/Users/priyavir/Desktop/pandas/survey_results_public.csv')

# %%
schema_df=pd.read_csv('D:/Users/priyavir/Desktop/pandas/survey_results_schema.csv')

# %%
df ['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df ['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.loc[0:2, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df_people.set_index('email')
# Out:
#                  first    last
# email
# corey@email.com  corey  shafer
# jane@email.com    jane     doe
# john@email.com    john     doe

# %%
df_people.set_index('email', inplace= True)

# %%
df_people
# Out:
#                  first    last
# email
# corey@email.com  corey  shafer
# jane@email.com    jane     doe
# john@email.com    john     doe

# %%
df_people.iloc[0]
# Out:
# first     corey
# last     shafer
# Name: corey@email.com, dtype: object

# %%
df_people.reset_index (inplace=True)

# %%
df_people
# Out:
#              email  first    last
# 0  corey@email.com  corey  shafer
# 1   jane@email.com   jane     doe
# 2   john@email.com   john     doe

# %%
df = pd.read_csv('D:/Users/priyavir/Desktop/pandas/survey_results_public.csv',index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.sort_index()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88879                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
# 88881                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88883                          I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 88883                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88881                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
# 88879                          I am a developer by profession      Yes
# ...                                                       ...      ...
# 5                              I am a developer by profession      Yes
# 4                              I am a developer by profession       No
# 3           I am not primarily a developer, but I write co...      Yes
# 2                      I am a student who is learning to code       No
# 1                      I am a student who is learning to code      Yes
#
#                            OpenSourcer  \
# Respondent
# 88883       Once a month or more often
# ...

# %%
df_people['last']=='doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt= (df_people['last']=='doe')

# %%
df_people[filt]
# Out:
#             email first last
# 1  jane@email.com  jane  doe
# 2  john@email.com  john  doe

# %%
df_people.loc[filt]
# Out:
#             email first last
# 1  jane@email.com  jane  doe
# 2  john@email.com  john  doe

# %%
df_people.loc [filt, 'email']
# Out:
# 1    jane@email.com
# 2    john@email.com
# Name: email, dtype: object

# %%
filt = (df_people['last']=='doe') & (df_people['first'] == 'john')

# %%
df_people[filt]
# Out:
#             email first last
# 2  john@email.com  john  doe

# %%
filt = (df_people['last']=='doe') | (df_people['first'] == 'john')

# %%
df_people[filt]
# Out:
#             email first last
# 1  jane@email.com  jane  doe
# 2  john@email.com  john  doe

# %%
df_people.loc[-filt]
# Out:
#              email  first    last
# 0  corey@email.com  corey  shafer

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', 'India', 'Germany']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 4        United States
# 8                India
# 10               India
# 13       United States
# 14             Germany
#              ...
# 83862            India
# 84299            India
# 85642    United States
# 86012            India
# 88282    United States
# Name: Country, Length: 35876, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df_people.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
df_people.columns = [x.upper() for x in df_people.columns]

# %%
df_people
# Out:
#              EMAIL  FIRST    LAST
# 0  corey@email.com  corey  shafer
# 1   jane@email.com   jane     doe
# 2   john@email.com   john     doe

# %%
df_people.columns= df_people.columns.str.replace(' ', '')

# %%
df_people
df_people.columns = [x.lower() for x in df_people.columns]

# %%
df_people
# Out:
#              email  first    last
# 0  corey@email.com  corey  shafer
# 1   jane@email.com   jane     doe
# 2   john@email.com   john     doe

# %%
df_people.rename(columns= {'first' : 'first_name'})
# Out:
#              email first_name    last
# 0  corey@email.com      corey  shafer
# 1   jane@email.com       jane     doe
# 2   john@email.com       john     doe

# %%
df_people.loc[2]=['john','smith','smith@mail.com']

# %%
df_people
# Out:
#              email  first            last
# 0  corey@email.com  corey          shafer
# 1   jane@email.com   jane             doe
# 2             john  smith  smith@mail.com

# %%
df_people ['email'] .apply(len)
# Out:
# 0    15
# 1    14
# 2     4
# Name: email, dtype: int64

# %%
df_people
# Out:
#              email  first            last
# 0  corey@email.com  corey          shafer
# 1   jane@email.com   jane             doe
# 2             john  smith  smith@mail.com

# %%
df_people.apply(len)
# Out:
# email    3
# first    3
# last     3
# dtype: int64

# %%
len(df_people['email'])
# Out:
# 3

# %%
df_people.apply(pd.Series.min)
# Out:
# email    corey@email.com
# first              corey
# last                 doe
# dtype: object

# %%
df_people.applymap(len)
# Out:
#    email  first  last
# 0     15      5     6
# 1     14      4     3
# 2      4      5    14

# %%
df_people.applymap(str.lower)
# Out:
#              email  first            last
# 0  corey@email.com  corey          shafer
# 1   jane@email.com   jane             doe
# 2             john  smith  smith@mail.com

# %%
df_people['first'].map({'corey' : 'chris'})
# Out:
# 0    chris
# 1      NaN
# 2      NaN
# Name: first, dtype: object

# %%
df_people['first'].replace({'corey' : 'chris'})
# Out:
# 0    chris
# 1     jane
# 2    smith
# Name: first, dtype: object

# %%
df['Hobbyist'].map({'yes' : True , 'no' : False})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hobbyist'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-fd527066a5a6> in <module>
# ...

# %%
df
# Out:
#                                         _M_A_I_N_B_R_A_N_C_H_  \
# Respondent
# 1                      I am a student who is learning to code
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 88377                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
# 88863                                                     NaN
#
#            _H_O_B_B_Y_I_S_T_  \
# Respondent
# 1                        Yes
# 2                         No
# 3                        Yes
# 4                         No
# 5                        Yes
# ...

# %%
df.columns= df.columns.str.replace('_', '')

# %%
df.columns= df.columns.str.lower()

# %%
df
# Out:
#                                                    mainbranch hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   opensourcer  \
# Respondent
# ...

# %%
df['hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: hobbyist, Length: 88883, dtype: object

# %%
df['hobbyist'].map({'Yes' : True , 'No' : False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: hobbyist, Length: 88883, dtype: bool

# %%
df_people['full_name']= df_people['first'] + ' ' + df_people['last']

# %%
df_people
# Out:
#              email  first            last             full_name
# 0  corey@email.com  corey          shafer          corey shafer
# 1   jane@email.com   jane             doe              jane doe
# 2             john  smith  smith@mail.com  smith smith@mail.com

# %%
df_people.drop(columns=['first','last'])
# Out:
#              email             full_name
# 0  corey@email.com          corey shafer
# 1   jane@email.com              jane doe
# 2             john  smith smith@mail.com

# %%
df_people
# Out:
#              email  first            last             full_name
# 0  corey@email.com  corey          shafer          corey shafer
# 1   jane@email.com   jane             doe              jane doe
# 2             john  smith  smith@mail.com  smith smith@mail.com

# %%
df_people['full_name'].str.split(' ', expand=True)
# Out:
#        0               1
# 0  corey          shafer
# 1   jane             doe
# 2  smith  smith@mail.com

# %%
df_people[['first','last']]= df_people['full_name'].str.split(' ', expand=True)

# %%
df_people
# Out:
#              email  first            last             full_name
# 0  corey@email.com  corey          shafer          corey shafer
# 1   jane@email.com   jane             doe              jane doe
# 2             john  smith  smith@mail.com  smith smith@mail.com

# %%
df_people.append({'first' : 'tony'},ignore_index = True)
# Out:
#              email  first            last             full_name
# 0  corey@email.com  corey          shafer          corey shafer
# 1   jane@email.com   jane             doe              jane doe
# 2             john  smith  smith@mail.com  smith smith@mail.com
# 3              NaN   tony             NaN                   NaN

# %%
df_people.drop(index=1)
# Out:
#              email  first            last             full_name
# 0  corey@email.com  corey          shafer          corey shafer
# 2             john  smith  smith@mail.com  smith smith@mail.com

# %%
df_people
# Out:
#              email  first            last             full_name
# 0  corey@email.com  corey          shafer          corey shafer
# 1   jane@email.com   jane             doe              jane doe
# 2             john  smith  smith@mail.com  smith smith@mail.com

# %%
filt = df_people['last']=='doe'
df_people.drop (index= df_people[filt].index)
# Out:
#              email  first            last             full_name
# 0  corey@email.com  corey          shafer          corey shafer
# 2             john  smith  smith@mail.com  smith smith@mail.com

# %%
df_people.sort_values(by='last')
# Out:
#              email  first            last             full_name
# 1   jane@email.com   jane             doe              jane doe
# 0  corey@email.com  corey          shafer          corey shafer
# 2             john  smith  smith@mail.com  smith smith@mail.com

# %%
df_people = df_people.replace[{'smith@mail.com' : 'smith'}]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-216-b5aed9e9f323> in <module>
# ----> 1 df_people = df_people.replace[{'smith@mail.com' : 'smith'}]
#
# TypeError: 'method' object is not subscriptable

# %%
df_people.loc[0,['last','email']]= ['smith','smith@mail.com']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-228-17140e043ebd> in <module>
# ----> 1 df_people.iloc[0,['last','email']]= ['smith','smith@mail.com']
#
# AttributeError: 'list' object has no attribute 'iloc'

# %%
df_people
# Out:
# ['smith', 'smith@mail.com']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-224-215061288676> in <module>
# ----> 1 df_people['full_name'].str.split(' ', expand=True)
#
# TypeError: list indices must be integers or slices, not str

# %%
people = { "first" : ["corey","jane","john"],
           "last"  : ["shafer","doe","doe"],
            "email" : ["corey@email.com","jane@email.com","john@email.com"]
         }

# %%
df_people= pd.DataFrame (people)

# %%
df_people
# Out:
#    first    last            email
# 0  corey  shafer  corey@email.com
# 1   jane     doe   jane@email.com
# 2   john     doe   john@email.com

# %%
df.sort_values(by='country', inplace=True)

# %%
df ['country'].head(20)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# 63019    Afghanistan
# 6417     Afghanistan
# 40000    Afghanistan
# 88731    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 62525    Afghanistan
# 49702    Afghanistan
# 33178    Afghanistan
# 60946    Afghanistan
# 86362    Afghanistan
# 88582    Afghanistan
# 28638    Afghanistan
# 722      Afghanistan
# 26340    Afghanistan
# Name: country, dtype: object

# %%
df.nlargest(10,'convertedcomp')
# Out:
#                                                    mainbranch hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 78151                          I am a developer by profession      Yes
# 80200                          I am a developer by profession      Yes
# 52132                          I am a developer by profession      Yes
# 75561                          I am a developer by profession      Yes
# 32250                          I am a developer by profession      Yes
#
#                                                   opensourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df['convertedcomp'].median()
# Out:
# 57287.0

# %%
df.describe()
# Out:
#           comptotal  convertedcomp   workweekhrs    coderevhrs           age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['convertedcomp'].count()
# Out:
# 55823

# %%
df['hobbyist']
# Out:
# Respondent
# 39258    Yes
# 63129    Yes
# 85715     No
# 50767     No
# 2782     Yes
#         ...
# 88062     No
# 88076     No
# 88601     No
# 88802     No
# 88816     No
# Name: hobbyist, Length: 88883, dtype: object

# %%
df['hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: hobbyist, dtype: int64

# %%
df['socialmedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: socialmedia, dtype: float64

# %%
country_group = df.groupby (['country'])

# %%
country_group.get_group('India')
# Out:
#                                                    mainbranch hobbyist  \
# Respondent
# 32379                          I am a developer by profession       No
# 81742                          I am a developer by profession      Yes
# 75299                          I am a developer by profession      Yes
# 66901                          I am a developer by profession      Yes
# 23018                          I am a developer by profession      Yes
# ...                                                       ...      ...
# 79628                          I am a developer by profession       No
# 40151                                                     NaN       No
# 76400       I am not primarily a developer, but I write co...       No
# 30928                          I am a developer by profession       No
# 30452                  I am a student who is learning to code       No
#
#                                                   opensourcer  \
# Respondent
# ...

# %%
country_group['socialmedia'].value_counts().loc['India']
# Out:
# socialmedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: socialmedia, dtype: int64

# %%
country_group['convertedcomp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_group['convertedcomp'].agg(['median','mean']).loc['Germany']
# Out:
# median     63016.000000
# mean      109256.884066
# Name: Germany, dtype: float64

# %%
country_uses_python = country_group['languageworkedwith'].apply(lambda x : x.str.contains('python').sum())

# %%
country_uses_python
# Out:
# country
# Afghanistan                             0
# Albania                                 0
# Algeria                                 0
# Andorra                                 0
# Angola                                  0
#                                        ..
# Venezuela, Bolivarian Republic of...    0
# Viet Nam                                0
# Yemen                                   0
# Zambia                                  0
# Zimbabwe                                0
# Name: languageworkedwith, Length: 179, dtype: int64

# %%
country_respondents = df['country'].value_counts()
python_df = pd.concat([country_respondents, country_uses_python],axis='columns',sort=False)

# %%
python_df
# Out:
#                        country  languageworkedwith
# United States            20949                   0
# India                     9061                   0
# Germany                   5866                   0
# United Kingdom            5737                   0
# Canada                    3395                   0
# ...                        ...                 ...
# Papua New Guinea             1                   0
# Niger                        1                   0
# Tonga                        1                   0
# Sao Tome and Principe        1                   0
# Timor-Leste                  1                   0
#
# [179 rows x 2 columns]

# %%
country_uses_python = country_group['languageworkedwith']

# %%
country_uses_python

# %%
filt= df['country']=='india'
df.loc[filt]['languageworkedwith'].str.contains('python').sum()
# Out:
# 0

# %%
df['country']
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
#             ...
# 88062            NaN
# 88076            NaN
# 88601            NaN
# 88802            NaN
# 88816            NaN
# Name: country, Length: 88883, dtype: object

# %%
df = pd.read_csv('D:/Users/priyavir/Desktop/pandas/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df['Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
filt= df['Country']=='India'
df[filt]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt= df['Country']=='India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_group = df.groupby (['Country'])
country_uses_python = country_group['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
country_respondents = df['Country'].value_counts()
python_df = pd.concat([country_respondents, country_uses_python],axis='columns',sort=False)

# %%
python_df
# Out:
#                        Country  LanguageWorkedWith
# United States            20949               10083
# India                     9061                3105
# Germany                   5866                2451
# United Kingdom            5737                2384
# Canada                    3395                1558
# ...                        ...                 ...
# Papua New Guinea             1                   0
# Niger                        1                   1
# Tonga                        1                   0
# Sao Tome and Principe        1                   1
# Timor-Leste                  1                   1
#
# [179 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
people = { "first" : ["corey","jane","john","chris",np.nan, None,"NA"],
           "last"  : ["shafer","doe","doe","schafer", np.nan, np.nan,"Missing"],
            "email" : ["corey@email.com","jane@email.com","john@email.com",None, np.nan,'anonymas@mail.com',"NA"],
            "age" : ["33","55","63","36",None,None,"missing"]
         }

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#    first     last              email      age
# 0  corey   shafer    corey@email.com       33
# 1   jane      doe     jane@email.com       55
# 2   john      doe     john@email.com       63
# 3  chris  schafer               None       36
# 4    NaN      NaN                NaN     None
# 5   None      NaN  anonymas@mail.com     None
# 6     NA  Missing                 NA  missing

# %%
df.dropna()
# Out:
#    first     last            email      age
# 0  corey   shafer  corey@email.com       33
# 1   jane      doe   jane@email.com       55
# 2   john      doe   john@email.com       63
# 6     NA  Missing               NA  missing

# %%
df.dropna(axis='index', how='all')
# Out:
#    first     last              email      age
# 0  corey   shafer    corey@email.com       33
# 1   jane      doe     jane@email.com       55
# 2   john      doe     john@email.com       63
# 3  chris  schafer               None       36
# 5   None      NaN  anonymas@mail.com     None
# 6     NA  Missing                 NA  missing

# %%
df.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df.dropna(axis='index', subset=['email'])
# Out:
#    first     last              email      age
# 0  corey   shafer    corey@email.com       33
# 1   jane      doe     jane@email.com       55
# 2   john      doe     john@email.com       63
# 5   None      NaN  anonymas@mail.com     None
# 6     NA  Missing                 NA  missing

# %%
df.replace('NA',np.nan,inplace=True)
df.replace('Missing', np.nan,inplace=True)
df.replace('missing', np.nan,inplace=True)
df
# Out:
#    first     last              email   age
# 0  corey   shafer    corey@email.com    33
# 1   jane      doe     jane@email.com    55
# 2   john      doe     john@email.com    63
# 3  chris  schafer               None    36
# 4    NaN      NaN                NaN  None
# 5   None      NaN  anonymas@mail.com  None
# 6    NaN      NaN                NaN   NaN

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('MISSING')
# Out:
#      first     last              email      age
# 0    corey   shafer    corey@email.com       33
# 1     jane      doe     jane@email.com       55
# 2     john      doe     john@email.com       63
# 3    chris  schafer            MISSING       36
# 4  MISSING  MISSING            MISSING  MISSING
# 5  MISSING  MISSING  anonymas@mail.com  MISSING
# 6  MISSING  MISSING            MISSING  MISSING

# %%
df['YearsCode'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YearsCode'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-351-261d33078e9a> in <module>
# ----> 1 df['YearsCode'].unique()
#
# ...

# %%
df = pd.read_csv('D:/Users/priyavir/Desktop/pandas/survey_results_public.csv')

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('More than 50 years',51 ,inplace=True)

# %%
df['YearsCode'].replace('Less than 1 year', 0 ,inplace=True)

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df['YearsCode'].mode()
# Out:
# 0    5.0
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('D:/Users/priyavir/Desktop/pandas/ETH_1H.csv')

# %%
df.head()
# Out:
#    Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0   1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1   1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2   1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3   1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4   1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
#
#     Close       Volume
# 0  150.39   650.188125
# 1  152.94  4277.567299
# 2  155.81   106.337279
# 3  157.18    55.244131
# 4  158.04   144.262622

# %%
df.shape
# Out:
# (34497, 8)

# %%
df.loc[0, 'Date']
# Out:
# '2020-04-16 00:00:00'

# %%
df['Date'] = pd.to_datetime(df['Date'] , format= '%Y-%m-%d %H:%M:%S')

# %%
df['Date']
# Out:
# 0       2020-04-16 00:00:00
# 1       2020-04-15 23:00:00
# 2       2020-04-15 22:00:00
# 3       2020-04-15 21:00:00
# 4       2020-04-15 20:00:00
#                 ...
# 34492   2016-05-09 17:00:00
# 34493   2016-05-09 16:00:00
# 34494   2016-05-09 15:00:00
# 34495   2016-05-09 14:00:00
# 34496   2016-05-09 13:00:00
# Name: Date, Length: 34497, dtype: datetime64[ns]

# %%
df.loc[0,'Date'].day_name()
# Out:
# 'Thursday'

# %%
df['Date'].dt.day_name()
# Out:
# 0         Thursday
# 1        Wednesday
# 2        Wednesday
# 3        Wednesday
# 4        Wednesday
#            ...
# 34492       Monday
# 34493       Monday
# 34494       Monday
# 34495       Monday
# 34496       Monday
# Name: Date, Length: 34497, dtype: object

# %%
df['dayofweek'] = df['Date'].dt.day_name()
df
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0       1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1       1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2       1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3       1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4       1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...               ...                 ...     ...     ...     ...     ...
# 34492      1462813200 2016-05-09 17:00:00  ETHUSD    9.83    9.83    9.48
# 34493      1462809600 2016-05-09 16:00:00  ETHUSD    9.99    9.99    9.79
# 34494      1462806000 2016-05-09 15:00:00  ETHUSD   10.00   10.00    9.99
# 34495      1462802400 2016-05-09 14:00:00  ETHUSD    9.55   10.00    9.55
# 34496      1462798800 2016-05-09 13:00:00  ETHUSD    0.00   12.00    0.00
#
#         Close       Volume  dayofweek
# 0      150.39   650.188125   Thursday
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2016-05-09 13:00:00')

# %%
 filt= (df['Date'] >= '2020')
 df.loc[filt]
# Out:
#       Unix Timestamp                Date  Symbol    Open    High     Low  \
# 0      1586995200000 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1      1586991600000 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2      1586988000000 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3      1586984400000 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4      1586980800000 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ...              ...                 ...     ...     ...     ...     ...
# 2540   1577851200000 2020-01-01 04:00:00  ETHUSD  129.83  129.96  129.13
# 2541   1577847600000 2020-01-01 03:00:00  ETHUSD  130.25  130.30  129.42
# 2542   1577844000000 2020-01-01 02:00:00  ETHUSD  129.95  130.58  129.95
# 2543   1577840400000 2020-01-01 01:00:00  ETHUSD  128.11  130.01  128.11
# 2544   1577836800000 2020-01-01 00:00:00  ETHUSD  128.84  128.84  128.07
#
#        Close       Volume  dayofweek
# 0     150.39   650.188125   Thursday
# ...

# %%
df
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-04-16 00:00:00   1586995200000  ETHUSD  152.94  152.94  150.39  150.39
# 2020-04-15 23:00:00   1586991600000  ETHUSD  155.81  155.81  151.39  152.94
# 2020-04-15 22:00:00   1586988000000  ETHUSD  157.18  157.30  155.32  155.81
# 2020-04-15 21:00:00   1586984400000  ETHUSD  158.04  158.31  157.16  157.18
# 2020-04-15 20:00:00   1586980800000  ETHUSD  157.10  158.10  156.87  158.04
# ...                             ...     ...     ...     ...     ...     ...
# 2016-05-09 17:00:00      1462813200  ETHUSD    9.83    9.83    9.48    9.49
# 2016-05-09 16:00:00      1462809600  ETHUSD    9.99    9.99    9.79    9.83
# 2016-05-09 15:00:00      1462806000  ETHUSD   10.00   10.00    9.99    9.99
# 2016-05-09 14:00:00      1462802400  ETHUSD    9.55   10.00    9.55   10.00
# 2016-05-09 13:00:00      1462798800  ETHUSD    0.00   12.00    0.00    9.55
#
#                           Volume  dayofweek
# ...

# %%
import numpy as np
df.loc['2019']
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2019-12-31 23:00:00   1577833200000  ETHUSD  128.68  128.85  127.82  128.84
# 2019-12-31 22:00:00   1577829600000  ETHUSD  128.40  128.93  127.77  128.68
# 2019-12-31 21:00:00   1577826000000  ETHUSD  127.87  128.41  127.81  128.40
# 2019-12-31 20:00:00   1577822400000  ETHUSD  127.86  128.30  127.86  127.87
# 2019-12-31 19:00:00   1577818800000  ETHUSD  128.78  128.78  127.86  127.86
# ...                             ...     ...     ...     ...     ...     ...
# 2019-01-01 04:00:00   1546315200000  ETHUSD  130.83  133.75  130.83  132.09
# 2019-01-01 03:00:00   1546311600000  ETHUSD  129.79  131.00  129.79  130.83
# 2019-01-01 02:00:00   1546308000000  ETHUSD  130.98  130.98  129.25  129.79
# 2019-01-01 01:00:00   1546304400000  ETHUSD  131.10  131.10  128.72  130.98
# 2019-01-01 00:00:00   1546300800000  ETHUSD  130.80  131.70  130.00  131.10
#
#                           Volume dayofweek
# Date
# ...

# %%
df.loc['2020-01-01' : '2019-02-01']
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-01-01 23:00:00   1577919600000  ETHUSD  129.91  130.25  129.35  130.25
# 2020-01-01 22:00:00   1577916000000  ETHUSD  131.31  131.31  129.53  129.91
# 2020-01-01 21:00:00   1577912400000  ETHUSD  131.73  131.92  131.19  131.31
# 2020-01-01 20:00:00   1577908800000  ETHUSD  131.40  131.74  131.07  131.73
# 2020-01-01 19:00:00   1577905200000  ETHUSD  131.45  131.71  131.00  131.40
# ...                             ...     ...     ...     ...     ...     ...
# 2019-02-01 04:00:00   1548993600000  ETHUSD  104.36  104.36  103.35  103.72
# 2019-02-01 03:00:00   1548990000000  ETHUSD  103.75  104.36  103.70  104.36
# 2019-02-01 02:00:00   1548986400000  ETHUSD  103.43  104.01  103.22  103.75
# 2019-02-01 01:00:00   1548982800000  ETHUSD  105.34  105.34  103.01  103.43
# 2019-02-01 00:00:00   1548979200000  ETHUSD  105.70  106.00  105.34  105.34
#
#                           Volume  dayofweek
# ...

# %%
df.loc['2020-01-01' : '2019-02-01']['Close'].mean()
# Out:
# 185.60840114470565

# %%
df['High'].resample('d').max()
# Out:
# Date
# 2016-05-09     12.00
# 2016-05-10      9.96
# 2016-05-11     10.47
# 2016-05-12     12.00
# 2016-05-13     11.59
#                ...
# 2020-04-12    165.37
# 2020-04-13    159.51
# 2020-04-14    162.15
# 2020-04-15    161.52
# 2020-04-16    152.94
# Freq: D, Name: High, Length: 1439, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
df2 = pd.DataFrame(
   ...:     {
   ...:         "A": 1.0,
   ...:         "B": pd.Timestamp("20130102"),
   ...:         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
   ...:         "D": np.array([3] * 4, dtype="int32"),
   ...:         "E": pd.Categorical(["test", "train", "test", "train"]),
   ...:         "F": "foo",
   ...:     }
   ...: )

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object
